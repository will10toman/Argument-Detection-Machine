# %%
import pandas as pd

# %%
claims = pd.read_csv('data/IBM_Debater_(R)_claim_sentences_search/data_sets/q_mc_train.csv')
evidence = pd.read_csv('data/IBM_Debater_(R)_wikipedia_evidence_dataset_29429.csv/wikipedia_evidence_dataset_29429.csv')

# %%
claims.head()
# Out:
#    id                      topic       mc  \
# 0  62  We should abandon Youtube  YouTube
# 1  62  We should abandon Youtube  YouTube
# 2  62  We should abandon Youtube  YouTube
# 3  62  We should abandon Youtube  YouTube
# 4  62  We should abandon Youtube  YouTube
#
#                                             sentence  \
# 0  On 21 May 2017, the second annual Sidemen char...
# 1  These videos are posted to sites such as YouTu...
# 2  On 11 December 2013, Albarn released a 21-seco...
# 3  All videos were later freely offered on Tankia...
# 4  November 14, 2007-A Vidster user on YouTube cr...
#
#                                               suffix  \
# 0                                  All Stars" [REF].
# 1  , where they often generate conflicting nation...
# 2  , which he had also shared on his Facebook and...
# 3                                                  .
# 4   created a community known as The Vidster Corn...
#
#                                               prefix  \
# ...

# %%
evidence.head()
# Out:
#                           Motion Text Dominant Concept  \
# 0  We should legalize doping in sport  Doping in sport
# 1  We should legalize doping in sport  Doping in sport
# 2  We should legalize doping in sport  Doping in sport
# 3  We should legalize doping in sport  Doping in sport
# 4  We should legalize doping in sport  Doping in sport
#
#                                             Evidence  acceptanceRate  \
# 0  Bakulin is coached by Viktor Chegin[REF] who h...        0.300000
# 1  Factors for determining tests may include: Phy...        0.066667
# 2  Rasmussen had previously been given two warnin...        0.214286
# 3  In 2001 and 2002 Simeoni was suspended for sev...        0.200000
# 4  Although the number of cases is low, the Basqu...        0.900000
#
#    Wikipedia article_id            Wikipedia article_title
# 0              17357560                     Sergey Bakulin
# 1                801647   United States Anti-Doping Agency
# ...
